# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
df1=pd.read_csv('train.csv', encoding='utf-8')
df2=pd.read_csv('test.csv', encoding='utf-8')
df2_org=df2
df1.drop(['PassengerId', 'Name', 'Age', 'SibSp'], axis=1, inplace=True)
df2.drop(['Name', 'Age', 'SibSp'], axis=1, inplace=True)

# %%
df1
# Out:
#      Survived  Pclass     Sex  Parch            Ticket     Fare Cabin Embarked
# 0           0       3    male      0         A/5 21171   7.2500   NaN        S
# 1           1       1  female      0          PC 17599  71.2833   C85        C
# 2           1       3  female      0  STON/O2. 3101282   7.9250   NaN        S
# 3           1       1  female      0            113803  53.1000  C123        S
# 4           0       3    male      0            373450   8.0500   NaN        S
# ..        ...     ...     ...    ...               ...      ...   ...      ...
# 886         0       2    male      0            211536  13.0000   NaN        S
# 887         1       1  female      0            112053  30.0000   B42        S
# 888         0       3  female      2        W./C. 6607  23.4500   NaN        S
# 889         1       1    male      0            111369  30.0000  C148        C
# 890         0       3    male      0            370376   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Apply LabelEncoder to all categorical columns
label_encoders = {}  # To store the encoders for each column
for col in df1.select_dtypes(include=['object', 'category']).columns:
    le = LabelEncoder()
    df1[col] = le.fit_transform(df1[col])
    df2[col] = le.fit_transform(df2[col])
    label_encoders[col] = le  # Save the encoder for inverse transform if needed

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)  # n_neighbors defines the number of neighbors to use
df1_imputed = pd.DataFrame(imputer.fit_transform(df1), columns=df1.columns)
df1=df1_imputed
df2_imputed = pd.DataFrame(imputer.fit_transform(df2), columns=df2.columns)
df2=df2_imputed

# %%
df1_imputed
# Out:
#      Survived  Pclass  Sex  Parch  Ticket     Fare  Cabin  Embarked
# 0         0.0     3.0  1.0    0.0   523.0   7.2500  147.0       2.0
# 1         1.0     1.0  0.0    0.0   596.0  71.2833   81.0       0.0
# 2         1.0     3.0  0.0    0.0   669.0   7.9250  147.0       2.0
# 3         1.0     1.0  0.0    0.0    49.0  53.1000   55.0       2.0
# 4         0.0     3.0  1.0    0.0   472.0   8.0500  147.0       2.0
# ..        ...     ...  ...    ...     ...      ...    ...       ...
# 886       0.0     2.0  1.0    0.0   101.0  13.0000  147.0       2.0
# 887       1.0     1.0  0.0    0.0    14.0  30.0000   30.0       2.0
# 888       0.0     3.0  0.0    2.0   675.0  23.4500  147.0       2.0
# 889       1.0     1.0  1.0    0.0     8.0  30.0000   60.0       0.0
# 890       0.0     3.0  1.0    0.0   466.0   7.7500  147.0       1.0
#
# [891 rows x 8 columns]

# %%
df2
# Out:
#      PassengerId  Pclass  Sex  Parch  Ticket      Fare  Cabin  Embarked
# 0          892.0     3.0  1.0    0.0   152.0    7.8292   76.0       1.0
# 1          893.0     3.0  0.0    0.0   221.0    7.0000   76.0       2.0
# 2          894.0     2.0  1.0    0.0    73.0    9.6875   76.0       1.0
# 3          895.0     3.0  1.0    0.0   147.0    8.6625   76.0       2.0
# 4          896.0     3.0  0.0    1.0   138.0   12.2875   76.0       2.0
# ..           ...     ...  ...    ...     ...       ...    ...       ...
# 413       1305.0     3.0  1.0    0.0   267.0    8.0500   76.0       2.0
# 414       1306.0     1.0  0.0    0.0   324.0  108.9000   22.0       0.0
# 415       1307.0     3.0  1.0    0.0   346.0    7.2500   76.0       2.0
# 416       1308.0     3.0  1.0    0.0   220.0    8.0500   76.0       2.0
# 417       1309.0     3.0  1.0    1.0   105.0   22.3583   76.0       0.0
#
# [418 rows x 8 columns]

# %%
#Correlation between numerical features and target
numeric_features=df1.select_dtypes(include=['int64','float64'])
correlation_matrix = numeric_features.corr()
correlation_with_target = correlation_matrix['Survived'].sort_values(ascending=False)
print(correlation_with_target)
# Out:
# Survived    1.000000
# Fare        0.257307
# Parch       0.081629
# Embarked   -0.163517
# Ticket     -0.164549
# Cabin      -0.254888
# Pclass     -0.338481
# Sex        -0.543351
# Name: Survived, dtype: float64

# %%
import matplotlib.pyplot as plt
#visualize correlation
plt.figure(figsize=(10,8))
correlation_with_target.drop('Survived').plot(kind='bar', color='red')
plt.title('Correlation with Survived')
plt.xlabel('Features')
plt.ylabel('Correlation')
# Out:
# Text(0, 0.5, 'Correlation')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Assuming df1 is your DataFrame with 'Survived' as the target column

# Initialize StandardScaler
scaler_X = StandardScaler()

# Separate features and target variable
X = df1.drop('Survived', axis=1)  # Drop the target column from the features
Y = df1['Survived']  # Target variable

# Fit and transform the feature data
X_scaled = scaler_X.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.01, random_state=42)

# Build a simple neural network model
model = Sequential([
    Dense(64, activation='relu', input_dim=X_train.shape[1]),  # Input layer with 64 neurons
    Dense(32, activation='relu'),                             # Hidden layer with 32 neurons
    Dense(1, activation='sigmoid')                            # Output layer (binary classification)
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, Y_train, epochs=20, batch_size=32, validation_data=(X_test, Y_test), verbose=1)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(f"Accuracy: {accuracy:.2f}")

# Generate predictions
y_pred = (model.predict(X_test) > 0.5).astype(int)

# Classification Report
print("\nClassification Report:")
print(classification_report(Y_test, y_pred))

# Plot training history (Optional)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# C:\Users\Rafid\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6146 - loss: 0.8386 - val_accuracy: 0.8889 - val_loss: 0.4654
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7906 - loss: 0.5174 - val_accuracy: 0.5556 - val_loss: 0.5299
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7926 - loss: 0.4515 - val_accuracy: 0.8889 - val_loss: 0.2842
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8001 - loss: 0.4321 - val_accuracy: 0.8889 - val_loss: 0.3975
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8142 - loss: 0.4843 - val_accuracy: 0.8889 - val_loss: 0.4355
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8004 - loss: 0.4664 - val_accuracy: 0.5556 - val_loss: 0.5538
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8073 - loss: 0.4295 - val_accuracy: 0.8889 - val_loss: 0.3368
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7958 - loss: 0.4506 - val_accuracy: 0.8889 - val_loss: 0.2301
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7798 - loss: 0.5061 - val_accuracy: 0.8889 - val_loss: 0.3397
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8143 - loss: 0.4479 - val_accuracy: 0.8889 - val_loss: 0.3874
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7859 - loss: 0.4506 - val_accuracy: 0.8889 - val_loss: 0.2379
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7897 - loss: 0.4578 - val_accuracy: 0.8889 - val_loss: 0.2674
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8047 - loss: 0.4262 - val_accuracy: 0.8889 - val_loss: 0.2948
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8159 - loss: 0.4368 - val_accuracy: 0.8889 - val_loss: 0.2553
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8014 - loss: 0.4370 - val_accuracy: 0.8889 - val_loss: 0.3127
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8119 - loss: 0.4570 - val_accuracy: 0.7778 - val_loss: 0.3258
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7885 - loss: 0.4956 - val_accuracy: 0.8889 - val_loss: 0.3488
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8215 - loss: 0.4049 - val_accuracy: 0.8889 - val_loss: 0.3510
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7825 - loss: 0.4660 - val_accuracy: 0.7778 - val_loss: 0.3751
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7726 - loss: 0.4711 - val_accuracy: 0.5556 - val_loss: 0.5464
# Accuracy: 0.56
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.43      1.00      0.60         3
#          1.0       1.00      0.33      0.50         6
#
#     accuracy                           0.56         9
#    macro avg       0.71      0.67      0.55         9
# weighted avg       0.81      0.56      0.53         9

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Assuming df1 is your original training DataFrame and df2 is the new test dataset
# Ensure that df2 is loaded correctly

# Separate features from df1 and df2
X_train = df1.drop('Survived', axis=1)
Y_train = df1['Survived']

# Initialize StandardScaler
scaler_X = StandardScaler()

# Scale the features in the training set
X_train_scaled = scaler_X.fit_transform(X_train)

# Scale the features in the test set (using the scaler from the training data)
X1_test = df2[X_train.columns]  # Ensure same feature columns in both training and test set
X1_test_scaled = scaler_X.transform(X1_test)  # Don't fit, just transform with the already-fitted scaler

# Build the neural network model
model = Sequential([
    Dense(64, activation='relu', input_dim=X_train_scaled.shape[1]),  # Input layer with 64 neurons
    Dense(32, activation='relu'),  # Hidden layer with 32 neurons
    Dense(1, activation='sigmoid')  # Output layer (binary classification)
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model on the training data
model.fit(X_train_scaled, Y_train, epochs=20, batch_size=32, verbose=1)

# Make predictions on the test set
test_predictions = (model.predict(X1_test_scaled) > 0.5).astype(int)

# Save the predictions to a CSV file, including the 'PassengerId' column
predictions_df = pd.DataFrame({'PassengerId': df2['PassengerId'], 'Survived': test_predictions.flatten()})

# Convert 'PassengerId' to integer type
predictions_df['PassengerId'] = predictions_df['PassengerId'].astype('Int32')

# Save predictions to CSV
predictions_df.to_csv('neural_network_predictions.csv', index=False)

print("Training on the full dataset is complete. Predictions saved!")
# Out:
# Epoch 1/20
# C:\Users\Rafid\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7070 - loss: 0.5826
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8076 - loss: 0.4811
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7792 - loss: 0.4884
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8060 - loss: 0.4537
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7917 - loss: 0.4756
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8003 - loss: 0.4460
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8252 - loss: 0.4109
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.4922
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7786 - loss: 0.4587
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8085 - loss: 0.4385
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8146 - loss: 0.4359
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8117 - loss: 0.4322
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8135 - loss: 0.4539
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8079 - loss: 0.4315
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8097 - loss: 0.4357
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8134 - loss: 0.4347
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7906 - loss: 0.4536
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7936 - loss: 0.4313
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8316 - loss: 0.4168
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8268 - loss: 0.4113
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Training on the full dataset is complete. Predictions saved!

# %%
predictions_df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
